# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sqlalchemy import engine
import pyodbc 
import urllib
from sqlalchemy import create_engine
import snowflake.connector

# %%
from urllib.parse import quote_plus

# %%
#"mongodb+srv://MichalDataBase:Qwer1997@@cluster0.o2qdros.mongodb.net/?retryWrites=true&w=majority",
import pymongo

username = "MichalDataBase"
password = "Qwer1997@"
cluster = "cluster0.o2qdros.mongodb.net"
jwt_secret = "pstzpcrvnebs1eq67ltn"  # Replace with your JWT secret


# URL-encode the username and password
escaped_username = quote_plus(username)
escaped_password = quote_plus(password)

# Build the MongoDB connection string
connection_string = f"mongodb+srv://MichalDataBase:{escaped_password}@cluster0.o2qdros.mongodb.net/?retryWrites=true&w=majority"

# Create a MongoClient to connect to the MongoDB cluster
client = pymongo.MongoClient(connection_string)

# Access your database and collection as needed

# %%
# Access your database
db = client["test"]

# %%
# Access your "users" collection
users_collection = db["users"]

# Query the collection to read data
# For example, you can retrieve all documents in the "users" collection
user_documents = users_collection.find()

# Iterate through the results
for user in user_documents:
    print(user)
# Out:
# {'_id': ObjectId('648f1d25891f2162103c2f16'), 'role': 'User', 'name': 'jklhkhkj', 'email': 'test1234790@gmail.com', 'avatar': '//www.gravatar.com/avatar/097c02b42ac98979c8644d4f249a22d4?s=200&r=g&d=mm', 'password': '$2a$10$ZBFboM2JpG.dPmWEygVyp.3qHQ8ysZQAOZF8jk/dZZGpKS53ExD8C', 'date': datetime.datetime(2023, 6, 18, 15, 5, 9, 928000), '__v': 0}
# {'_id': ObjectId('6491b97be71beb27cca9fffc'), 'role': 'User', 'name': 'jklhkhkj', 'email': 'klkljljk@gmail.com', 'avatar': '//www.gravatar.com/avatar/4bbe0ac799342cf8ed5a732a964f1d1a?s=200&r=g&d=mm', 'password': '$2a$10$nTeLQ6QCWK4yyjTUDNVhpu6gDb60TERrIPm0CDBEBLq3WCsD7j4ly', 'date': datetime.datetime(2023, 6, 20, 14, 36, 43, 60000), '__v': 0}
# {'_id': ObjectId('64879882f25b3e27c8ba983d'), 'role': 'User', 'name': 'Michal123456', 'email': 'jkowal999888@gmail.com', 'avatar': '//www.gravatar.com/avatar/49e0b24d2fdbb4b1725b1ae85260f8ec?s=200&r=g&d=mm', 'password': '$2a$10$b.odLEMwoMtPSDpyRy09J.2xIrs7q1MXG3rRoy5p.t4meUmM.yA/2', 'date': datetime.datetime(2023, 6, 12, 22, 13, 22, 919000), '__v': 0}
# {'_id': ObjectId('6488c1a135597d2820c8f9ed'), 'role': 'User', 'name': 'ferdek12', 'email': 'test1234@gmail.com', 'avatar': '//www.gravatar.com/avatar/43f15fe253f6d1f85823bf8e8855e1df?s=200&r=g&d=mm', 'password': '$2a$10$B.iC2/xPOZJWtr7LFWdX/O14AFZRqWWX3utZ4mJInQ3Ei.LAg3sZG', 'date': datetime.datetime(2023, 6, 13, 19, 21, 5, 743000), '__v': 0}
# {'_id': ObjectId('64879ac61b962d585089480f'), 'role': 'User', 'name': 'jklhkhkj', 'email': 'michalmatracz@gmail.com', 'avatar': '//www.gravatar.com/avatar/fab420e7f843a3e639c6be138509aeaf?s=200&r=g&d=mm', 'password': '$2a$10$EYJuxMuUv89poLtELr5omeVkc.HHt5dRPHzfOBN4jbDuRqWfCIsKC', 'date': datetime.datetime(2023, 6, 12, 22, 23, 2, 286000), '__v': 0}
# {'_id': ObjectId('6487980bf25b3e27c8ba9830'), 'role': 'User', 'name': 'Jaku brzydsok', 'email': 'test123@gmail.com', 'avatar': '//www.gravatar.com/avatar/9a93efa79aa9f5d35e14bc55a3e16dc4?s=200&r=g&d=mm', 'password': '$2a$10$2IxN6YE65cYOh6ve9X78POab24.0RW0faV2ezsLswxA7X9yfdSSLS', 'date': datetime.datetime(2023, 6, 12, 22, 11, 23, 818000), '__v': 0}
# {'_id': ObjectId('6488c27e0d60a91838d67631'), 'role': 'User', 'name': 'jklhkhkj', 'email': 'test12347@gmail.com', 'avatar': '//www.gravatar.com/avatar/1c840e32c7a131a6b7249415caa26c28?s=200&r=g&d=mm', 'password': '$2a$10$tWz/Hx064L49LD3sGwDJxuiOpGweS0N689RASTgOw.832QznbM3de', 'date': datetime.datetime(2023, 6, 13, 19, 24, 46, 84000), '__v': 0}
# {'_id': ObjectId('652d9035eed1ba45f0c0d5f5'), 'role': 'User', 'name': '123456cf', 'email': 'kdnkscj@gmail.com', 'avatar': '//www.gravatar.com/avatar/4144b06a29d5b75be566a1060f7176dc?s=200&r=g&d=mm', 'password': '$2a$10$BOt7ABPycJA.aMEpbRkDb.xSb0YeBPKBiQN2RlixOJ1YD6qepX.2G', 'date': datetime.datetime(2023, 10, 16, 19, 34, 13, 214000), '__v': 0}
# {'_id': ObjectId('653137b87fce7f5748255140'), 'role': 'User', 'name': 'Michał Matracz', 'email': 'michalmatracz123@gmail.com', 'avatar': '//www.gravatar.com/avatar/bcfa40b5ae55d64c9b8c46d3426c682f?s=200&r=g&d=mm', 'password': '$2a$10$pKJ/erZ0vDFZW19Bu8/jkOXuVU.7/MjuW/QBUCnv.0GPcNkbvoQA2', 'date': datetime.datetime(2023, 10, 19, 14, 5, 44, 281000), '__v': 0}
# {'_id': ObjectId('653acd05f760995f48319cdf'), 'role': 'User', 'name': 'Pimpek', 'email': 'abcd@gmail.com', 'avatar': '//www.gravatar.com/avatar/46040c38d1cbe8ffcd3df6c8ba787951?s=200&r=g&d=mm', 'password': '$2a$10$TXPaCLmpr.SPvnk7veEh1.Fan6xwJRessUUSlTY813AyWLuQUQTW2', 'date': datetime.datetime(2023, 10, 26, 20, 33, 9, 941000), '__v': 0}

# %%
from datetime import datetime

# %%
sales_schema = {
    "id": {
        "type": int,
        "required": True,
    },
    "status": {
        "type": str,
        "required": True,
    },
    "date": {
        "type": datetime,
        "required": True,
    },
    "description": {
        "type": str,
        "required": True,
    },
    "quantity": {
        "type": int,
        "required": True,
    },
    "unitPrice": {
        "type": float,
        "required": True,
    },
    "total": {
        "type": float,
        "required": True,
    },
    "orderNumber": {
        "type": int,
        "required": True,
    },
    "category": {
        "type": str,
        "required": True,
    },
    "paymentMethod": {
        "type": str,
        "required": True,
    },
    "orderDate": {
        "type": datetime,
        "required": True,
    },
    "revenue": {
        "type": float,
        "required": True,
    },
    "year": {
        "type": int,
        "required": True,
    },
    "month": {
        "type": int,
        "required": True,
    },
    "dateYear": {
        "type": str,
        "required": True,
    },
    "dateMonth": {
        "type": str,
        "required": True,
    },
    "fiscalYear": {
        "type": str,
        "required": True,
    },
    "product": {
        "type": int,
    },
}

# %%
users_collection = db["users"]

# Find and read data from the "users" collection
for user in users_collection.find():
    print(user)
# Out:
# {'_id': ObjectId('648f1d25891f2162103c2f16'), 'role': 'User', 'name': 'jklhkhkj', 'email': 'test1234790@gmail.com', 'avatar': '//www.gravatar.com/avatar/097c02b42ac98979c8644d4f249a22d4?s=200&r=g&d=mm', 'password': '$2a$10$ZBFboM2JpG.dPmWEygVyp.3qHQ8ysZQAOZF8jk/dZZGpKS53ExD8C', 'date': datetime.datetime(2023, 6, 18, 15, 5, 9, 928000), '__v': 0}
# {'_id': ObjectId('6491b97be71beb27cca9fffc'), 'role': 'User', 'name': 'jklhkhkj', 'email': 'klkljljk@gmail.com', 'avatar': '//www.gravatar.com/avatar/4bbe0ac799342cf8ed5a732a964f1d1a?s=200&r=g&d=mm', 'password': '$2a$10$nTeLQ6QCWK4yyjTUDNVhpu6gDb60TERrIPm0CDBEBLq3WCsD7j4ly', 'date': datetime.datetime(2023, 6, 20, 14, 36, 43, 60000), '__v': 0}
# {'_id': ObjectId('64879882f25b3e27c8ba983d'), 'role': 'User', 'name': 'Michal123456', 'email': 'jkowal999888@gmail.com', 'avatar': '//www.gravatar.com/avatar/49e0b24d2fdbb4b1725b1ae85260f8ec?s=200&r=g&d=mm', 'password': '$2a$10$b.odLEMwoMtPSDpyRy09J.2xIrs7q1MXG3rRoy5p.t4meUmM.yA/2', 'date': datetime.datetime(2023, 6, 12, 22, 13, 22, 919000), '__v': 0}
# {'_id': ObjectId('6488c1a135597d2820c8f9ed'), 'role': 'User', 'name': 'ferdek12', 'email': 'test1234@gmail.com', 'avatar': '//www.gravatar.com/avatar/43f15fe253f6d1f85823bf8e8855e1df?s=200&r=g&d=mm', 'password': '$2a$10$B.iC2/xPOZJWtr7LFWdX/O14AFZRqWWX3utZ4mJInQ3Ei.LAg3sZG', 'date': datetime.datetime(2023, 6, 13, 19, 21, 5, 743000), '__v': 0}
# {'_id': ObjectId('64879ac61b962d585089480f'), 'role': 'User', 'name': 'jklhkhkj', 'email': 'michalmatracz@gmail.com', 'avatar': '//www.gravatar.com/avatar/fab420e7f843a3e639c6be138509aeaf?s=200&r=g&d=mm', 'password': '$2a$10$EYJuxMuUv89poLtELr5omeVkc.HHt5dRPHzfOBN4jbDuRqWfCIsKC', 'date': datetime.datetime(2023, 6, 12, 22, 23, 2, 286000), '__v': 0}
# {'_id': ObjectId('6487980bf25b3e27c8ba9830'), 'role': 'User', 'name': 'Jaku brzydsok', 'email': 'test123@gmail.com', 'avatar': '//www.gravatar.com/avatar/9a93efa79aa9f5d35e14bc55a3e16dc4?s=200&r=g&d=mm', 'password': '$2a$10$2IxN6YE65cYOh6ve9X78POab24.0RW0faV2ezsLswxA7X9yfdSSLS', 'date': datetime.datetime(2023, 6, 12, 22, 11, 23, 818000), '__v': 0}
# {'_id': ObjectId('6488c27e0d60a91838d67631'), 'role': 'User', 'name': 'jklhkhkj', 'email': 'test12347@gmail.com', 'avatar': '//www.gravatar.com/avatar/1c840e32c7a131a6b7249415caa26c28?s=200&r=g&d=mm', 'password': '$2a$10$tWz/Hx064L49LD3sGwDJxuiOpGweS0N689RASTgOw.832QznbM3de', 'date': datetime.datetime(2023, 6, 13, 19, 24, 46, 84000), '__v': 0}
# {'_id': ObjectId('652d9035eed1ba45f0c0d5f5'), 'role': 'User', 'name': '123456cf', 'email': 'kdnkscj@gmail.com', 'avatar': '//www.gravatar.com/avatar/4144b06a29d5b75be566a1060f7176dc?s=200&r=g&d=mm', 'password': '$2a$10$BOt7ABPycJA.aMEpbRkDb.xSb0YeBPKBiQN2RlixOJ1YD6qepX.2G', 'date': datetime.datetime(2023, 10, 16, 19, 34, 13, 214000), '__v': 0}
# {'_id': ObjectId('653137b87fce7f5748255140'), 'role': 'User', 'name': 'Michał Matracz', 'email': 'michalmatracz123@gmail.com', 'avatar': '//www.gravatar.com/avatar/bcfa40b5ae55d64c9b8c46d3426c682f?s=200&r=g&d=mm', 'password': '$2a$10$pKJ/erZ0vDFZW19Bu8/jkOXuVU.7/MjuW/QBUCnv.0GPcNkbvoQA2', 'date': datetime.datetime(2023, 10, 19, 14, 5, 44, 281000), '__v': 0}
# {'_id': ObjectId('653acd05f760995f48319cdf'), 'role': 'User', 'name': 'Pimpek', 'email': 'abcd@gmail.com', 'avatar': '//www.gravatar.com/avatar/46040c38d1cbe8ffcd3df6c8ba787951?s=200&r=g&d=mm', 'password': '$2a$10$TXPaCLmpr.SPvnk7veEh1.Fan6xwJRessUUSlTY813AyWLuQUQTW2', 'date': datetime.datetime(2023, 10, 26, 20, 33, 9, 941000), '__v': 0}

# %%
#Connect with ms sql server instance (two databases)

pd.set_option('expand_frame_repr', True)
pd.set_option("display.max_rows", 1000)
pd.set_option('max_colwidth',100)



server = r'DESKTOP-06UQ0CT\NEW_SALES2023'


database_Sales_E_Commerce = 'Sales_E_Commerce'


Driver= 'ODBC Driver 17 for SQL Server'


username = 'myusername' 
password = 'mypassword'



Database_con_E_commerce = f'mssql://@{server}/{database_Sales_E_Commerce}?driver={Driver}'





engine_E_commerce = create_engine(Database_con_E_commerce)




#Do pełnych setów
con_E_comerce = engine_E_commerce.connect()

# %%
df = pd.read_sql("Select * from PakistanSales", con_E_comerce)

# %%
df.size
# Out:
# 11690380

# %%
df.shape
# Out:
# (584519, 20)

# %%
field_data_types = {
    "item_id": int,
    "status": str,
    "created_at": pd.to_datetime,  # Convert to datetime
    "sku": str,
    "price": float,
    "qty_ordered": int,
    "grand_total": float,
    "increment_id": str,
    "Category name": str,
    "discount_amount": float,
    "payment_method": str,
    "Working Date": str,  # You might want to change the data type to datetime if necessary
    "BI Status": str,
    "Merchant Value": str,
    "Year": int,
    "Month": int,
    "Customer Since": str,  # You might want to change the data type to datetime if necessary
    "M-Y": str,
    "FY": str,
    "Customer ID": float,
}

# %%
data_to_insert = []
for record in df.to_dict(orient="records"):
    data_to_insert.append({key: field_data_types[key](value) for key, value in record.items()})

# %%
data_to_insert
# Out:
# [{'item_id': 211133,
#   'status': 'canceled',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Body Spray Free',
#   'price': 240.0,
#   'qty_ordered': 1,
#   'grand_total': 240.0,
#   'increment_id': '100147444',
#   'Category name': 'Beauty & Grooming',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Gross',
#   'Merchant Value': ' 240 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 2.0},
#  {'item_id': 211134,
#   'status': 'canceled',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'Ego_UP0017-999-MR0',
#   'price': 2450.0,
#   'qty_ordered': 1,
#   'grand_total': 2450.0,
#   'increment_id': '100147445',
#   'Category name': "Women's Fashion",
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Gross',
#   'Merchant Value': ' 2,450 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 3.0},
#  {'item_id': 211135,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'kcc_krone deal',
#   'price': 360.0,
#   'qty_ordered': 1,
#   'grand_total': 60.0,
#   'increment_id': '100147446',
#   'Category name': 'Beauty & Grooming',
#   'discount_amount': 300.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 360 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 4.0},
#  {'item_id': 211136,
#   'status': 'order_refunded',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'BK7010400AG',
#   'price': 555.0,
#   'qty_ordered': 2,
#   'grand_total': 1110.0,
#   'increment_id': '100147447',
#   'Category name': 'Soghaat',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Valid',
#   'Merchant Value': ' 1,110 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 5.0},
#  {'item_id': 211137,
#   'status': 'canceled',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'UK_Namkino All In One 200 Gms',
#   'price': 80.0,
#   'qty_ordered': 1,
#   'grand_total': 80.0,
#   'increment_id': '100147448',
#   'Category name': 'Soghaat',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Gross',
#   'Merchant Value': ' 80 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 6.0},
#  {'item_id': 211138,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'kcc_krone deal',
#   'price': 360.0,
#   'qty_ordered': 1,
#   'grand_total': 60.0,
#   'increment_id': '100147449',
#   'Category name': 'Beauty & Grooming',
#   'discount_amount': 300.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 360 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 7.0},
#  {'item_id': 211139,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'UK_Namkino Mix Nimco 400 Gms',
#   'price': 170.0,
#   'qty_ordered': 1,
#   'grand_total': 170.0,
#   'increment_id': '100147450',
#   'Category name': 'Soghaat',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 170 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 6.0},
#  {'item_id': 211140,
#   'status': 'canceled',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'Apple iPhone 6S 64GB',
#   'price': 96499.0,
#   'qty_ordered': 1,
#   'grand_total': 96499.0,
#   'increment_id': '100147451',
#   'Category name': 'Mobiles & Tablets',
#   'discount_amount': 0.0,
#   'payment_method': 'ublcreditcard',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Gross',
#   'Merchant Value': ' 96,499 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 8.0},
#  {'item_id': 211141,
#   'status': 'canceled',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'Apple iPhone 6S 64GB',
#   'price': 96499.0,
#   'qty_ordered': 1,
#   'grand_total': 96499.0,
#   'increment_id': '100147452',
#   'Category name': 'Mobiles & Tablets',
#   'discount_amount': 0.0,
#   'payment_method': 'mygateway',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Gross',
#   'Merchant Value': ' 96,499 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 8.0},
#  {'item_id': 211142,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'GFC_Pedestal Myga Cross Base (Special Guard) 24"',
#   'price': 5500.0,
#   'qty_ordered': 1,
#   'grand_total': 5500.0,
#   'increment_id': '100147453',
#   'Category name': 'Appliances',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 5,500 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 9.0},
#  {'item_id': 211143,
#   'status': 'received',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'BK1070200PL',
#   'price': 210.0,
#   'qty_ordered': 1,
#   'grand_total': 366.0,
#   'increment_id': '100147454',
#   'Category name': 'Soghaat',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Valid',
#   'Merchant Value': ' 210 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 10.0},
#  {'item_id': 211144,
#   'status': 'received',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'BK1130200CF',
#   'price': 156.0,
#   'qty_ordered': 1,
#   'grand_total': 366.0,
#   'increment_id': '100147454',
#   'Category name': 'Soghaat',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Valid',
#   'Merchant Value': ' 156 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 10.0},
#  {'item_id': 211145,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'kcc_Sultanat',
#   'price': 120.0,
#   'qty_ordered': 1,
#   'grand_total': 120.0,
#   'increment_id': '100147455',
#   'Category name': 'Home & Living',
#   'discount_amount': 0.0,
#   'payment_method': 'ublcreditcard',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 120 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 11.0},
#  {'item_id': 211146,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'kcc_glamour deal',
#   'price': 320.0,
#   'qty_ordered': 1,
#   'grand_total': 0.0,
#   'increment_id': '100147456',
#   'Category name': 'Beauty & Grooming',
#   'discount_amount': 0.0,
#   'payment_method': 'customercredit',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 320 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 12.0},
#  {'item_id': 211147,
#   'status': 'canceled',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'Assetmen_MD-346-M',
#   'price': 1550.0,
#   'qty_ordered': 1,
#   'grand_total': 1550.0,
#   'increment_id': '100147457',
#   'Category name': "Men's Fashion",
#   'discount_amount': 0.0,
#   'payment_method': 'ublcreditcard',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Gross',
#   'Merchant Value': ' 1,550 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 11.0},
#  {'item_id': 211149,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'cr_DATES WITH CASHEW-400 GM',
#   'price': 420.0,
#   'qty_ordered': 1,
#   'grand_total': 1270.0,
#   'increment_id': '100147458',
#   'Category name': 'Soghaat',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 420 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 13.0},
#  {'item_id': 211150,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'UK_Gift Box Mix Dry Fruit Sweets 500 Gms',
#   'price': 360.0,
#   'qty_ordered': 1,
#   'grand_total': 1270.0,
#   'increment_id': '100147458',
#   'Category name': 'Soghaat',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 360 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 13.0},
#  {'item_id': 211151,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'itter_AB 1199',
#   'price': 490.0,
#   'qty_ordered': 1,
#   'grand_total': 1270.0,
#   'increment_id': '100147458',
#   'Category name': 'Beauty & Grooming',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 490 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 13.0},
#  {'item_id': 211152,
#   'status': 'canceled',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'RL_B005',
#   'price': 899.25,
#   'qty_ordered': 1,
#   'grand_total': 2118.25,
#   'increment_id': '100147459',
#   'Category name': 'Home & Living',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Gross',
#   'Merchant Value': ' 899 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 14.0},
#  {'item_id': 211153,
#   'status': 'canceled',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'bed&rest_S7',
#   'price': 899.0,
#   'qty_ordered': 1,
#   'grand_total': 2118.25,
#   'increment_id': '100147459',
#   'Category name': 'Home & Living',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Gross',
#   'Merchant Value': ' 899 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 14.0},
#  {'item_id': 211154,
#   'status': 'canceled',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'L&L_LLHLE8224S',
#   'price': 320.0,
#   'qty_ordered': 1,
#   'grand_total': 2118.25,
#   'increment_id': '100147459',
#   'Category name': 'Home & Living',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Gross',
#   'Merchant Value': ' 320 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 14.0},
#  {'item_id': 211155,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'J&J_JJR-4',
#   'price': 149.0,
#   'qty_ordered': 1,
#   'grand_total': 298.0,
#   'increment_id': '100147460',
#   'Category name': 'Kids & Baby',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 149 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 15.0},
#  {'item_id': 211156,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'J&J_JJR-20',
#   'price': 149.0,
#   'qty_ordered': 1,
#   'grand_total': 298.0,
#   'increment_id': '100147460',
#   'Category name': 'Kids & Baby',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 149 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 15.0},
#  {'item_id': 211157,
#   'status': 'order_refunded',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'D Lend a Helping Hand',
#   'price': 1000.0,
#   'qty_ordered': 1,
#   'grand_total': 0.0,
#   'increment_id': '100147461',
#   'Category name': 'Undefined',
#   'discount_amount': 0.0,
#   'payment_method': 'customercredit',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Valid',
#   'Merchant Value': ' 1,000 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 16.0},
#  {'item_id': 211158,
#   'status': 'order_refunded',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'Mochika_M0001112-12',
#   'price': 1913.0,
#   'qty_ordered': 1,
#   'grand_total': 3826.0,
#   'increment_id': '100147462',
#   'Category name': "Men's Fashion",
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Valid',
#   'Merchant Value': ' 1,913 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 17.0},
#  {'item_id': 211160,
#   'status': 'order_refunded',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'Mochika_M0001112-8',
#   'price': 1913.0,
#   'qty_ordered': 1,
#   'grand_total': 3826.0,
#   'increment_id': '100147462',
#   'Category name': "Men's Fashion",
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Valid',
#   'Merchant Value': ' 1,913 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 17.0},
#  {'item_id': 211162,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'SKMT_Blood Test',
#   'price': 500.0,
#   'qty_ordered': 1,
#   'grand_total': 0.0,
#   'increment_id': '100147463',
#   'Category name': 'Others',
#   'discount_amount': 0.0,
#   'payment_method': 'customercredit',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 500 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 16.0},
#  {'item_id': 211163,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'SKMT_Medicine',
#   'price': 100.0,
#   'qty_ordered': 5,
#   'grand_total': 0.0,
#   'increment_id': '100147463',
#   'Category name': 'Others',
#   'discount_amount': 0.0,
#   'payment_method': 'customercredit',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 500 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 16.0},
#  {'item_id': 211164,
#   'status': 'canceled',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'sputnik_701/5-11',
#   'price': 1500.0,
#   'qty_ordered': 2,
#   'grand_total': 3000.0,
#   'increment_id': '100147464',
#   'Category name': "Men's Fashion",
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Gross',
#   'Merchant Value': ' 3,000 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 18.0},
#  {'item_id': 211166,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'Ctees-Black Zip- Up Hoodie-XL',
#   'price': 450.0,
#   'qty_ordered': 1,
#   'grand_total': 450.0,
#   'increment_id': '100147465',
#   'Category name': 'Kids & Baby',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 450 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 19.0},
#  {'item_id': 211168,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'Samsung Galaxy J5',
#   'price': 20999.0,
#   'qty_ordered': 1,
#   'grand_total': 20999.0,
#   'increment_id': '100147466',
#   'Category name': 'Mobiles & Tablets',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 20,999 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 20.0},
#  {'item_id': 211169,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'kcc_krone deal',
#   'price': 360.0,
#   'qty_ordered': 1,
#   'grand_total': 360.0,
#   'increment_id': '100147467',
#   'Category name': 'Beauty & Grooming',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 360 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 20.0},
#  {'item_id': 211170,
#   'status': 'refund',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'Veet_4',
#   'price': 165.0,
#   'qty_ordered': 1,
#   'grand_total': 300.0,
#   'increment_id': '100147468',
#   'Category name': 'Beauty & Grooming',
#   'discount_amount': 82.5,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Valid',
#   'Merchant Value': ' 165 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 21.0},
#  {'item_id': 211171,
#   'status': 'refund',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'RS_Gulab jaman Tin',
#   'price': 435.0,
#   'qty_ordered': 1,
#   'grand_total': 300.0,
#   'increment_id': '100147468',
#   'Category name': 'Soghaat',
#   'discount_amount': 217.5,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Valid',
#   'Merchant Value': ' 435 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 21.0},
#  {'item_id': 211172,
#   'status': 'canceled',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'cr_PEANUT SALTY-200 GM',
#   'price': 90.0,
#   'qty_ordered': 1,
#   'grand_total': 940.0,
#   'increment_id': '100147469',
#   'Category name': 'Soghaat',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Gross',
#   'Merchant Value': ' 90 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 22.0},
#  {'item_id': 211173,
#   'status': 'canceled',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'Oriflame_21557',
#   'price': 850.0,
#   'qty_ordered': 1,
#   'grand_total': 940.0,
#   'increment_id': '100147469',
#   'Category name': 'Beauty & Grooming',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Gross',
#   'Merchant Value': ' 850 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 22.0},
#  {'item_id': 211174,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'JBS_TAT-128',
#   'price': 3672.0,
#   'qty_ordered': 1,
#   'grand_total': 3672.0,
#   'increment_id': '100147470',
#   'Category name': 'Home & Living',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 3,672 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 23.0},
#  {'item_id': 211175,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'cr_PEANUT SALTY-200 GM',
#   'price': 90.0,
#   'qty_ordered': 1,
#   'grand_total': 740.0,
#   'increment_id': '100147471',
#   'Category name': 'Soghaat',
#   'discount_amount': 19.15,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 90 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 22.0},
#  {'item_id': 211176,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'Oriflame_21557',
#   'price': 850.0,
#   'qty_ordered': 1,
#   'grand_total': 740.0,
#   'increment_id': '100147471',
#   'Category name': 'Beauty & Grooming',
#   'discount_amount': 180.85,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 850 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 22.0},
#  {'item_id': 211177,
#   'status': 'order_refunded',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'Ajmery_BRR-590-M',
#   'price': 899.0,
#   'qty_ordered': 1,
#   'grand_total': 899.0,
#   'increment_id': '100147472',
#   'Category name': "Men's Fashion",
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Valid',
#   'Merchant Value': ' 899 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 24.0},
#  {'item_id': 211179,
#   'status': 'canceled',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'HOS_GUCFW75',
#   'price': 7400.0,
#   'qty_ordered': 1,
#   'grand_total': 11000.0,
#   'increment_id': '100147473',
#   'Category name': 'Beauty & Grooming',
#   'discount_amount': 0.0,
#   'payment_method': 'mygateway',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Gross',
#   'Merchant Value': ' 7,400 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 25.0},
#  {'item_id': 211180,
#   'status': 'canceled',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'Lexon_LL116B-Blue',
#   'price': 3600.0,
#   'qty_ordered': 1,
#   'grand_total': 11000.0,
#   'increment_id': '100147473',
#   'Category name': 'Mobiles & Tablets',
#   'discount_amount': 0.0,
#   'payment_method': 'mygateway',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Gross',
#   'Merchant Value': ' 3,600 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 25.0},
#  {'item_id': 211182,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'kcc_Fantasy Perfumed Talcum Powder-200gm',
#   'price': 143.0,
#   'qty_ordered': 1,
#   'grand_total': 168.0,
#   'increment_id': '100147474',
#   'Category name': 'Beauty & Grooming',
#   'discount_amount': 77.72,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 143 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 22.0},
#  {'item_id': 211184,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': '2Zee_SC6',
#   'price': 225.0,
#   'qty_ordered': 1,
#   'grand_total': 168.0,
#   'increment_id': '100147474',
#   'Category name': 'Beauty & Grooming',
#   'discount_amount': 122.28,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 225 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 22.0},
#  {'item_id': 211185,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'Q MOBILE Noir X20',
#   'price': 4500.0,
#   'qty_ordered': 1,
#   'grand_total': 4500.0,
#   'increment_id': '100147475',
#   'Category name': 'Mobiles & Tablets',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 4,500 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 26.0},
#  {'item_id': 211186,
#   'status': 'canceled',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'rehaab_RJ160047',
#   'price': 3156.0,
#   'qty_ordered': 1,
#   'grand_total': 6152.0,
#   'increment_id': '100147476',
#   'Category name': "Women's Fashion",
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Gross',
#   'Merchant Value': ' 3,156 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 27.0},
#  {'item_id': 211187,
#   'status': 'canceled',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'Farah_3-B',
#   'price': 2996.0,
#   'qty_ordered': 1,
#   'grand_total': 6152.0,
#   'increment_id': '100147476',
#   'Category name': "Women's Fashion",
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Gross',
#   'Merchant Value': ' 2,996 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 27.0},
#  {'item_id': 211188,
#   'status': 'canceled',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'RS_Sohan Halwa Tin',
#   'price': 300.0,
#   'qty_ordered': 2,
#   'grand_total': 2210.0,
#   'increment_id': '100147477',
#   'Category name': 'Soghaat',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Gross',
#   'Merchant Value': ' 600 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 28.0},
#  {'item_id': 211189,
#   'status': 'canceled',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'UK_Soan Papdi Original 250 Gms',
#   'price': 150.0,
#   'qty_ordered': 2,
#   'grand_total': 2210.0,
#   'increment_id': '100147477',
#   'Category name': 'Soghaat',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Gross',
#   'Merchant Value': ' 300 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 28.0},
#  {'item_id': 211190,
#   'status': 'canceled',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'UK_Gift Box Soghaat 500 Gms',
#   'price': 465.0,
#   'qty_ordered': 2,
#   'grand_total': 2210.0,
#   'increment_id': '100147477',
#   'Category name': 'Soghaat',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Gross',
#   'Merchant Value': ' 930 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 28.0},
#  {'item_id': 211191,
#   'status': 'canceled',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'RS_Double Delight',
#   'price': 380.0,
#   'qty_ordered': 1,
#   'grand_total': 2210.0,
#   'increment_id': '100147477',
#   'Category name': 'Soghaat',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Gross',
#   'Merchant Value': ' 380 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 28.0},
#  {'item_id': 211192,
#   'status': 'canceled',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'Al Muhafiz Sohan Halwa Almond',
#   'price': 350.0,
#   'qty_ordered': 1,
#   'grand_total': 350.0,
#   'increment_id': '100147478',
#   'Category name': 'Soghaat',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Gross',
#   'Merchant Value': ' 350 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 29.0},
#  {'item_id': 211193,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'UK_Gift Box Baklawa 500 Gms',
#   'price': 425.0,
#   'qty_ordered': 1,
#   'grand_total': 425.0,
#   'increment_id': '100147479',
#   'Category name': 'Soghaat',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 425 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 30.0},
#  {'item_id': 211194,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'sputnik_2146/6-8',
#   'price': 850.0,
#   'qty_ordered': 1,
#   'grand_total': 850.0,
#   'increment_id': '100147480',
#   'Category name': "Women's Fashion",
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 850 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 31.0},
#  {'item_id': 211196,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'kkc_Kingtox 450ml Classic Green All Insect Killer Spray',
#   'price': 251.0,
#   'qty_ordered': 1,
#   'grand_total': 251.0,
#   'increment_id': '100147481',
#   'Category name': 'Home & Living',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 251 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 32.0},
#  {'item_id': 211197,
#   'status': 'order_refunded',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'kcc_krone deal',
#   'price': 360.0,
#   'qty_ordered': 1,
#   'grand_total': 360.0,
#   'increment_id': '100147482',
#   'Category name': 'Beauty & Grooming',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Valid',
#   'Merchant Value': ' 360 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 33.0},
#  {'item_id': 211198,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'Al Muhafiz Sohan Halwa Walnut',
#   'price': 510.0,
#   'qty_ordered': 1,
#   'grand_total': 835.0,
#   'increment_id': '100147483',
#   'Category name': 'Soghaat',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 510 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 34.0},
#  {'item_id': 211199,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'RS_Honey Dry Fruit Halwa',
#   'price': 325.0,
#   'qty_ordered': 1,
#   'grand_total': 835.0,
#   'increment_id': '100147483',
#   'Category name': 'Soghaat',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 325 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 34.0},
#  {'item_id': 211200,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'itter_AB 1214',
#   'price': 300.0,
#   'qty_ordered': 1,
#   'grand_total': 300.0,
#   'increment_id': '100147484',
#   'Category name': 'Beauty & Grooming',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 300 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 35.0},
#  {'item_id': 211202,
#   'status': 'order_refunded',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'Eco Star_40U557',
#   'price': 30417.0,
#   'qty_ordered': 1,
#   'grand_total': 30417.0,
#   'increment_id': '100147486',
#   'Category name': 'Entertainment',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Valid',
#   'Merchant Value': ' 30,417 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 36.0},
#  {'item_id': 211201,
#   'status': 'order_refunded',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'kcc_krone deal',
#   'price': 360.0,
#   'qty_ordered': 1,
#   'grand_total': 360.0,
#   'increment_id': '100147485',
#   'Category name': 'Beauty & Grooming',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Valid',
#   'Merchant Value': ' 360 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 33.0},
#  {'item_id': 211203,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'Al Muhafiz Sohan Halwa Almond',
#   'price': 350.0,
#   'qty_ordered': 2,
#   'grand_total': 700.0,
#   'increment_id': '100147487',
#   'Category name': 'Soghaat',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 700 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 37.0},
#  {'item_id': 211204,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'Orient_OR-6057 GX LGFD LV',
#   'price': 45250.0,
#   'qty_ordered': 1,
#   'grand_total': 45250.0,
#   'increment_id': '100147488',
#   'Category name': 'Appliances',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 45,250 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 38.0},
#  {'item_id': 211205,
#   'status': 'canceled',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'HOS_JPGCW100',
#   'price': 8100.0,
#   'qty_ordered': 3,
#   'grand_total': 24588.0,
#   'increment_id': '100147489',
#   'Category name': 'Beauty & Grooming',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Gross',
#   'Merchant Value': ' 24,300 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 39.0},
#  {'item_id': 211206,
#   'status': 'canceled',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'kkc_Jasmine King Air Freshener',
#   'price': 144.0,
#   'qty_ordered': 2,
#   'grand_total': 24588.0,
#   'increment_id': '100147489',
#   'Category name': 'Home & Living',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Gross',
#   'Merchant Value': ' 288 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 39.0},
#  {'item_id': 211207,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'asimjofaeanew_5A',
#   'price': 5597.0,
#   'qty_ordered': 1,
#   'grand_total': 5597.0,
#   'increment_id': '100147490',
#   'Category name': "Women's Fashion",
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 5,597 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 40.0},
#  {'item_id': 211208,
#   'status': 'order_refunded',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'ajmery_F9-981',
#   'price': 999.0,
#   'qty_ordered': 1,
#   'grand_total': 999.0,
#   'increment_id': '100147491',
#   'Category name': "Men's Fashion",
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Valid',
#   'Merchant Value': ' 999 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 35.0},
#  {'item_id': 211209,
#   'status': 'refund',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'hijabh_JILBAB-C (1)-52x',
#   'price': 4950.0,
#   'qty_ordered': 1,
#   'grand_total': 4950.0,
#   'increment_id': '100147492',
#   'Category name': "Women's Fashion",
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Valid',
#   'Merchant Value': ' 4,950 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 40.0},
#  {'item_id': 211211,
#   'status': 'order_refunded',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'noritake_NTM163M',
#   'price': 805.0,
#   'qty_ordered': 1,
#   'grand_total': 805.0,
#   'increment_id': '100147493',
#   'Category name': 'Home & Living',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Valid',
#   'Merchant Value': ' 805 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 41.0},
#  {'item_id': 211212,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'kcc_krone deal',
#   'price': 360.0,
#   'qty_ordered': 1,
#   'grand_total': 360.0,
#   'increment_id': '100147494',
#   'Category name': 'Beauty & Grooming',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 360 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 35.0},
#  {'item_id': 211213,
#   'status': 'order_refunded',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'RS_Habshi Halwa Tin',
#   'price': 280.0,
#   'qty_ordered': 1,
#   'grand_total': 280.0,
#   'increment_id': '100147495',
#   'Category name': 'Soghaat',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Valid',
#   'Merchant Value': ' 280 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 35.0},
#  {'item_id': 211214,
#   'status': 'canceled',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'sentiments_WRK1612',
#   'price': 1.0,
#   'qty_ordered': 1,
#   'grand_total': 1.0,
#   'increment_id': '100147496',
#   'Category name': 'Undefined',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Gross',
#   'Merchant Value': ' 1 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 33.0},
#  {'item_id': 211215,
#   'status': 'order_refunded',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'bata_comfit-8613714-43-9',
#   'price': 999.0,
#   'qty_ordered': 1,
#   'grand_total': 999.0,
#   'increment_id': '100147497',
#   'Category name': "Men's Fashion",
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Valid',
#   'Merchant Value': ' 999 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 42.0},
#  {'item_id': 211217,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'kcc_krone deal',
#   'price': 360.0,
#   'qty_ordered': 1,
#   'grand_total': 360.0,
#   'increment_id': '100147498',
#   'Category name': 'Beauty & Grooming',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 360 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 43.0},
#  {'item_id': 211218,
#   'status': 'order_refunded',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'Al Muhafiz Sohan Halwa Almond',
#   'price': 350.0,
#   'qty_ordered': 1,
#   'grand_total': 350.0,
#   'increment_id': '100147499',
#   'Category name': 'Soghaat',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Valid',
#   'Merchant Value': ' 350 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 44.0},
#  {'item_id': 211219,
#   'status': 'order_refunded',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'Al Muhafiz Sohan Halwa Almond',
#   'price': 350.0,
#   'qty_ordered': 1,
#   'grand_total': 350.0,
#   'increment_id': '100147500',
#   'Category name': 'Soghaat',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Valid',
#   'Merchant Value': ' 350 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 44.0},
#  {'item_id': 211220,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'UK_Namkino Mix Nimco 8 Pcs Gift Pack',
#   'price': 760.0,
#   'qty_ordered': 1,
#   'grand_total': 1195.0,
#   'increment_id': '100147501',
#   'Category name': 'Soghaat',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 760 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 13.0},
#  {'item_id': 211221,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'RS_Gulab jaman Tin',
#   'price': 435.0,
#   'qty_ordered': 1,
#   'grand_total': 1195.0,
#   'increment_id': '100147501',
#   'Category name': 'Soghaat',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 435 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 13.0},
#  {'item_id': 211222,
#   'status': 'canceled',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'sentiments_WRK1612',
#   'price': 1.0,
#   'qty_ordered': 5,
#   'grand_total': 5.0,
#   'increment_id': '100147502',
#   'Category name': 'Undefined',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Gross',
#   'Merchant Value': ' 5 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 33.0},
#  {'item_id': 211223,
#   'status': 'canceled',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'sentiments_WRK1612',
#   'price': 1.0,
#   'qty_ordered': 2,
#   'grand_total': 2.0,
#   'increment_id': '100147503',
#   'Category name': 'Undefined',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Gross',
#   'Merchant Value': ' 2 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 33.0},
#  {'item_id': 211225,
#   'status': 'canceled',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'sentiments_WRK1612',
#   'price': 1.0,
#   'qty_ordered': 1,
#   'grand_total': 1.0,
#   'increment_id': '100147505',
#   'Category name': 'Undefined',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Gross',
#   'Merchant Value': ' 1 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 33.0},
#  {'item_id': 211224,
#   'status': 'received',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'kcc_krone deal',
#   'price': 360.0,
#   'qty_ordered': 1,
#   'grand_total': 360.0,
#   'increment_id': '100147504',
#   'Category name': 'Beauty & Grooming',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Valid',
#   'Merchant Value': ' 360 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 43.0},
#  {'item_id': 211226,
#   'status': 'received',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'kcc_glamour deal',
#   'price': 320.0,
#   'qty_ordered': 1,
#   'grand_total': 320.0,
#   'increment_id': '100147506',
#   'Category name': 'Beauty & Grooming',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Valid',
#   'Merchant Value': ' 320 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 43.0},
#  {'item_id': 211227,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'RS_Gulab jaman Tin',
#   'price': 435.0,
#   'qty_ordered': 1,
#   'grand_total': 1195.0,
#   'increment_id': '100147507',
#   'Category name': 'Soghaat',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 435 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 13.0},
#  {'item_id': 211228,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'UK_Namkino Mix Nimco 8 Pcs Gift Pack',
#   'price': 760.0,
#   'qty_ordered': 1,
#   'grand_total': 1195.0,
#   'increment_id': '100147507',
#   'Category name': 'Soghaat',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 760 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 13.0},
#  {'item_id': 211229,
#   'status': 'received',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Body Spray Free',
#   'price': 240.0,
#   'qty_ordered': 1,
#   'grand_total': 240.0,
#   'increment_id': '100147508',
#   'Category name': 'Beauty & Grooming',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Valid',
#   'Merchant Value': ' 240 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 43.0},
#  {'item_id': 211230,
#   'status': 'received',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'kcc_krone deal',
#   'price': 360.0,
#   'qty_ordered': 1,
#   'grand_total': 360.0,
#   'increment_id': '100147509',
#   'Category name': 'Beauty & Grooming',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Valid',
#   'Merchant Value': ' 360 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 43.0},
#  {'item_id': 211231,
#   'status': 'order_refunded',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'Inoxy_Inoxy Hair Miracle Elixir',
#   'price': 1875.0,
#   'qty_ordered': 1,
#   'grand_total': 1875.0,
#   'increment_id': '100147510',
#   'Category name': 'Beauty & Grooming',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Valid',
#   'Merchant Value': ' 1,875 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 45.0},
#  {'item_id': 211232,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'UK_Namkino Mix Nimco 8 Pcs Gift Pack',
#   'price': 760.0,
#   'qty_ordered': 1,
#   'grand_total': 1195.0,
#   'increment_id': '100147511',
#   'Category name': 'Soghaat',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 760 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 13.0},
#  {'item_id': 211233,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'RS_Chum Chum Tin',
#   'price': 435.0,
#   'qty_ordered': 1,
#   'grand_total': 1195.0,
#   'increment_id': '100147511',
#   'Category name': 'Soghaat',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 435 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 13.0},
#  {'item_id': 211234,
#   'status': 'received',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'kcc_krone deal',
#   'price': 360.0,
#   'qty_ordered': 1,
#   'grand_total': 360.0,
#   'increment_id': '100147512',
#   'Category name': 'Beauty & Grooming',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/1/2016',
#   'BI Status': 'Valid',
#   'Merchant Value': ' 360 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 43.0},
#  {'item_id': 211235,
#   'status': 'received',
#   'created_at': Timestamp('2016-07-01 00:00:00'),
#   'sku': 'kcc_krone deal',
#   'price': 360.0,
#   'qty_ordered': 1,
#   'grand_total': 360.0,
# ...
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 48.0},
#  {'item_id': 212258,
#   'status': 'order_refunded',
#   'created_at': Timestamp('2016-07-03 00:00:00'),
#   'sku': 'sputnik_701/D14-10',
#   'price': 1500.0,
#   'qty_ordered': 1,
#   'grand_total': 1500.0,
#   'increment_id': '100148180',
#   'Category name': "Men's Fashion",
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/3/2016',
#   'BI Status': 'Valid',
#   'Merchant Value': ' 1,500 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 372.0},
#  {'item_id': 212260,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-03 00:00:00'),
#   'sku': 'kcc_fresh',
#   'price': 180.0,
#   'qty_ordered': 1,
#   'grand_total': 180.0,
#   'increment_id': '100148181',
#   'Category name': 'Beauty & Grooming',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/3/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 180 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 373.0},
#  {'item_id': 212261,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-03 00:00:00'),
#   'sku': 'Hstyle_HW-2016156',
#   'price': 405.0,
#   'qty_ordered': 1,
#   'grand_total': 405.0,
#   'increment_id': '100148182',
#   'Category name': 'Beauty & Grooming',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/3/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 405 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 374.0},
#  {'item_id': 212262,
#   'status': 'order_refunded',
#   'created_at': Timestamp('2016-07-03 00:00:00'),
#   'sku': 'Veet_1',
#   'price': 165.0,
#   'qty_ordered': 1,
#   'grand_total': 165.0,
#   'increment_id': '100148183',
#   'Category name': 'Beauty & Grooming',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/3/2016',
#   'BI Status': 'Valid',
#   'Merchant Value': ' 165 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 375.0},
#  {'item_id': 212263,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-03 00:00:00'),
#   'sku': 'kcc_Harmony Perfumed Talcum Powder-200gm',
#   'price': 143.0,
#   'qty_ordered': 1,
#   'grand_total': 143.0,
#   'increment_id': '100148184',
#   'Category name': 'Beauty & Grooming',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/3/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 143 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 48.0},
#  {'item_id': 212265,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-03 00:00:00'),
#   'sku': 'rute2_Vit B 50 Complex 50 Tablets',
#   'price': 890.0,
#   'qty_ordered': 1,
#   'grand_total': 2090.0,
#   'increment_id': '100148185',
#   'Category name': 'Health & Sports',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/3/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 890 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 376.0},
#  {'item_id': 212266,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-03 00:00:00'),
#   'sku': 'vitamin_Ultra Whey Protein',
#   'price': 1200.0,
#   'qty_ordered': 1,
#   'grand_total': 2090.0,
#   'increment_id': '100148185',
#   'Category name': 'Health & Sports',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/3/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 1,200 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 376.0},
#  {'item_id': 212267,
#   'status': 'canceled',
#   'created_at': Timestamp('2016-07-03 00:00:00'),
#   'sku': 'MYWALET_MW-033-D1-BLACK',
#   'price': 1082.0,
#   'qty_ordered': 1,
#   'grand_total': 1082.0,
#   'increment_id': '100148186',
#   'Category name': "Men's Fashion",
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/3/2016',
#   'BI Status': 'Gross',
#   'Merchant Value': ' 1,082 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 377.0},
#  {'item_id': 212268,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-03 00:00:00'),
#   'sku': 'vitamin_Vita White',
#   'price': 960.0,
#   'qty_ordered': 2,
#   'grand_total': 1920.0,
#   'increment_id': '100148187',
#   'Category name': 'Health & Sports',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/3/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 1,920 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 378.0},
#  {'item_id': 212269,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-03 00:00:00'),
#   'sku': 'UK_Pheni 400 Gms',
#   'price': 150.0,
#   'qty_ordered': 1,
#   'grand_total': 150.0,
#   'increment_id': '100148188',
#   'Category name': 'Soghaat',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/3/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 150 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 93.0},
#  {'item_id': 212270,
#   'status': 'order_refunded',
#   'created_at': Timestamp('2016-07-03 00:00:00'),
#   'sku': 'vitamin_Royal Jelly 500',
#   'price': 640.0,
#   'qty_ordered': 1,
#   'grand_total': 640.0,
#   'increment_id': '100148189',
#   'Category name': 'Health & Sports',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/3/2016',
#   'BI Status': 'Valid',
#   'Merchant Value': ' 640 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 379.0},
#  {'item_id': 212271,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-03 00:00:00'),
#   'sku': 'VITAMIN_HAIR SKIN & NAIL FORMULA',
#   'price': 480.0,
#   'qty_ordered': 2,
#   'grand_total': 960.0,
#   'increment_id': '100148190',
#   'Category name': 'Health & Sports',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/3/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 960 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 378.0},
#  {'item_id': 212272,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-03 00:00:00'),
#   'sku': 'VITAMIN_WHITENING BB CREAM',
#   'price': 280.0,
#   'qty_ordered': 1,
#   'grand_total': 70.0,
#   'increment_id': '100148191',
#   'Category name': 'Beauty & Grooming',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/3/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 280 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 380.0},
#  {'item_id': 212273,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-03 00:00:00'),
#   'sku': 'alkhair_Black Seed Oil Softgel Capsules100  Cap bottle',
#   'price': 500.0,
#   'qty_ordered': 1,
#   'grand_total': 70.0,
#   'increment_id': '100148191',
#   'Category name': 'Undefined',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/3/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 500 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 380.0},
#  {'item_id': 212274,
#   'status': 'canceled',
#   'created_at': Timestamp('2016-07-03 00:00:00'),
#   'sku': 'vitamin_Vita White',
#   'price': 960.0,
#   'qty_ordered': 2,
#   'grand_total': 1920.0,
#   'increment_id': '100148192',
#   'Category name': 'Health & Sports',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/3/2016',
#   'BI Status': 'Gross',
#   'Merchant Value': ' 1,920 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 378.0},
#  {'item_id': 212275,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-03 00:00:00'),
#   'sku': 'sentiments_Ferrero Rocher Gift Box',
#   'price': 1.0,
#   'qty_ordered': 1,
#   'grand_total': 0.0,
#   'increment_id': '100148193',
#   'Category name': 'Undefined',
#   'discount_amount': 1.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/3/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 1 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 381.0},
#  {'item_id': 212276,
#   'status': 'canceled',
#   'created_at': Timestamp('2016-07-03 00:00:00'),
#   'sku': 'ESPICO_050-Fancy Nylon Bra-Black-34',
#   'price': 430.0,
#   'qty_ordered': 1,
#   'grand_total': 430.0,
#   'increment_id': '100148194',
#   'Category name': "Women's Fashion",
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/3/2016',
#   'BI Status': 'Gross',
#   'Merchant Value': ' 430 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 382.0},
#  {'item_id': 212278,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-03 00:00:00'),
#   'sku': 'JBS_SL-STOR-017',
#   'price': 100.0,
#   'qty_ordered': 1,
#   'grand_total': 180.0,
#   'increment_id': '100148195',
#   'Category name': 'Home & Living',
#   'discount_amount': 52.63,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/3/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 100 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 383.0},
#  {'item_id': 212279,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-03 00:00:00'),
#   'sku': 'JBS_SL-STOR-051',
#   'price': 100.0,
#   'qty_ordered': 1,
#   'grand_total': 180.0,
#   'increment_id': '100148195',
#   'Category name': 'Home & Living',
#   'discount_amount': 52.63,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/3/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 100 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 383.0},
#  {'item_id': 212280,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-03 00:00:00'),
#   'sku': 'JBS_SL-STOR-024',
#   'price': 180.0,
#   'qty_ordered': 1,
#   'grand_total': 180.0,
#   'increment_id': '100148195',
#   'Category name': 'Home & Living',
#   'discount_amount': 94.74,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/3/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 180 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 383.0},
#  {'item_id': 212281,
#   'status': 'canceled',
#   'created_at': Timestamp('2016-07-03 00:00:00'),
#   'sku': 'sputnik_177/9-10',
#   'price': 1500.0,
#   'qty_ordered': 1,
#   'grand_total': 1500.0,
#   'increment_id': '100148196',
#   'Category name': "Men's Fashion",
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/3/2016',
#   'BI Status': 'Gross',
#   'Merchant Value': ' 1,500 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 384.0},
#  {'item_id': 212283,
#   'status': 'canceled',
#   'created_at': Timestamp('2016-07-03 00:00:00'),
#   'sku': 'Audionic_DJ-106',
#   'price': 625.0,
#   'qty_ordered': 1,
#   'grand_total': 625.0,
#   'increment_id': '100148197',
#   'Category name': 'Computing',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/3/2016',
#   'BI Status': 'Gross',
#   'Merchant Value': ' 625 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 385.0},
#  {'item_id': 212284,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-03 00:00:00'),
#   'sku': 'sputnik_3444/10-9',
#   'price': 2000.0,
#   'qty_ordered': 1,
#   'grand_total': 2639.0,
#   'increment_id': '100148198',
#   'Category name': "Women's Fashion",
#   'discount_amount': 0.0,
#   'payment_method': 'ublcreditcard',
#   'Working Date': '7/3/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 2,000 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 386.0},
#  {'item_id': 212286,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-03 00:00:00'),
#   'sku': 'ihijab_PN039',
#   'price': 639.0,
#   'qty_ordered': 1,
#   'grand_total': 2639.0,
#   'increment_id': '100148198',
#   'Category name': "Women's Fashion",
#   'discount_amount': 0.0,
#   'payment_method': 'ublcreditcard',
#   'Working Date': '7/3/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 639 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 386.0},
#  {'item_id': 212287,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-03 00:00:00'),
#   'sku': 'Al Muhafiz Sohan Halwa Almond',
#   'price': 350.0,
#   'qty_ordered': 1,
#   'grand_total': 150.0,
#   'increment_id': '100148199',
#   'Category name': 'Soghaat',
#   'discount_amount': 200.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/3/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 350 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 387.0},
#  {'item_id': 212288,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-03 00:00:00'),
#   'sku': 'ajwa_Ajwa Seeds Powder',
#   'price': 900.0,
#   'qty_ordered': 1,
#   'grand_total': 1800.0,
#   'increment_id': '100148200',
#   'Category name': 'Health & Sports',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/3/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 900 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 388.0},
#  {'item_id': 212289,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-03 00:00:00'),
#   'sku': 'ajwa_Ajwa Dates Powder',
#   'price': 900.0,
#   'qty_ordered': 1,
#   'grand_total': 1800.0,
#   'increment_id': '100148200',
#   'Category name': 'Health & Sports',
#   'discount_amount': 0.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/3/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 900 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 388.0},
#  {'item_id': 212290,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-03 00:00:00'),
#   'sku': 'ESPICO_050-Fancy Nylon Bra-Black-34',
#   'price': 430.0,
#   'qty_ordered': 1,
#   'grand_total': 130.0,
#   'increment_id': '100148201',
#   'Category name': "Women's Fashion",
#   'discount_amount': 100.0,
#   'payment_method': 'mygateway',
#   'Working Date': '7/3/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 430 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 389.0},
#  {'item_id': 212292,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-03 00:00:00'),
#   'sku': 'ESPICO_Sports Bra-Skin-Free size',
#   'price': 480.0,
#   'qty_ordered': 1,
#   'grand_total': 280.0,
#   'increment_id': '100148202',
#   'Category name': "Women's Fashion",
#   'discount_amount': 200.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/3/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 480 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 382.0},
#  {'item_id': 212294,
#   'status': 'complete',
#   'created_at': Timestamp('2016-07-03 00:00:00'),
#   'sku': 'ESPICO_Classic Cotton-Skin-42',
#   'price': 350.0,
#   'qty_ordered': 1,
#   'grand_total': 250.0,
#   'increment_id': '100148203',
#   'Category name': "Women's Fashion",
#   'discount_amount': 100.0,
#   'payment_method': 'Cash On Delivery',
#   'Working Date': '7/3/2016',
#   'BI Status': 'Net',
#   'Merchant Value': ' 350 ',
#   'Year': 2016,
#   'Month': 7,
#   'Customer Since': '2016-7',
#   'M-Y': '7-2016',
#   'FY': 'FY17',
#   'Customer ID': 382.0},
#  ...]

# %%
collection_name = "Sales"

# Create the collection
sales2_collection = db[collection_name]

# Insert the data into the collection
sales2_collection.insert_many(data_to_insert)

# Print a message indicating the data has been inserted
print(f"Inserted {len(data_to_insert)} documents into the '{collection_name}' collection.")
# Out:
# Inserted 584519 documents into the 'Sales' collection.

# %%
# Out:
#         item_id            status created_at  \
# 0        211133          canceled 2016-07-01
# 1        211134          canceled 2016-07-01
# 2        211135          complete 2016-07-01
# 3        211136    order_refunded 2016-07-01
# 4        211137          canceled 2016-07-01
# ...         ...               ...        ...
# 584514   905204  Cash On Delivery 2018-08-28
# 584515   905205        processing 2018-08-28
# 584516   905206        processing 2018-08-28
# 584517   905207        processing 2018-08-28
# 584518   905208        processing 2018-08-28
#
#                                                                 sku     price  \
# 0       kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Body Spray Free     240.0
# 1                                                Ego_UP0017-999-MR0    2450.0
# 2                                                    kcc_krone deal     360.0
# 3                                                       BK7010400AG     555.0
# 4                                     UK_Namkino All In One 200 Gms      80.0
# ...                                                             ...       ...
# 584514                                          WOFSCE5AE00357AECDE     699.0
# 584515                                          MATHUA5AF70A7D1E50A   35599.0
# 584516                                          MATSAM5B6D7208C6D30  129999.0
# 584517                                          MATSAM5B1509B4696EA   87300.0
# 584518                                          MATSAM5B10F91A9B6AB  108640.0
#
#         qty_ordered  grand_total increment_id      Category name  \
# 0                 1        240.0    100147444  Beauty & Grooming
# 1                 1       2450.0    100147445    Women's Fashion
# 2                 1         60.0    100147446  Beauty & Grooming
# 3                 2       1110.0    100147447            Soghaat
# 4                 1         80.0    100147448            Soghaat
# ...             ...          ...          ...                ...
# 584514            1        849.0    100562385    Women's Fashion
# 584515            1      35899.0    100562386  Mobiles & Tablets
# 584516            2     652178.0    100562387  Mobiles & Tablets
# 584517            2     652178.0    100562387  Mobiles & Tablets
# 584518            2     652178.0    100562387  Mobiles & Tablets
#
#         discount_amount    payment_method Working Date BI Status  \
# 0                   0.0  Cash On Delivery     7/1/2016     Gross
# 1                   0.0  Cash On Delivery     7/1/2016     Gross
# 2                 300.0  Cash On Delivery     7/1/2016       Net
# 3                   0.0  Cash On Delivery     7/1/2016     Valid
# 4                   0.0  Cash On Delivery     7/1/2016     Gross
# ...                 ...               ...          ...       ...
# 584514              0.0  Cash On Delivery    8/28/2018     Valid
# 584515              0.0       bankalfalah    8/28/2018     Gross
# 584516              0.0       bankalfalah    8/28/2018     Gross
# 584517              0.0       bankalfalah    8/28/2018     Gross
# 584518              0.0       bankalfalah    8/28/2018     Gross
#
#        Merchant Value  Year  Month Customer Since     M-Y    FY  Customer ID
# 0                240   2016      7         2016-7  7-2016  FY17          2.0
# 1              2,450   2016      7         2016-7  7-2016  FY17          3.0
# 2                360   2016      7         2016-7  7-2016  FY17          4.0
# 3              1,110   2016      7         2016-7  7-2016  FY17          5.0
# 4                 80   2016      7         2016-7  7-2016  FY17          6.0
# ...               ...   ...    ...            ...     ...   ...          ...
# 584514           699   2018      8         2018-8  8-2018  FY19     115320.0
# 584515        35,599   2018      8         2018-8  8-2018  FY19     115326.0
# 584516       259,998   2018      8         2018-7  8-2018  FY19     113474.0
# 584517       174,600   2018      8         2018-7  8-2018  FY19     113474.0
# 584518       217,280   2018      8         2018-7  8-2018  FY19     113474.0
#
# [584519 rows x 20 columns]

# %%
# !pip install "pymongo[srv]"
# Out:
# Collecting pymongo[srv]
#   Obtaining dependency information for pymongo[srv] from https://files.pythonhosted.org/packages/4d/88/7b9bfad1ad6269e0b9e0bb39d093aabc27837da4ccb93391cda68f580984/pymongo-4.5.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading pymongo-4.5.0-cp311-cp311-win_amd64.whl.metadata (22 kB)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\programdata\anaconda3\lib\site-packages (from pymongo[srv]) (1.16.0)
# Downloading pymongo-4.5.0-cp311-cp311-win_amd64.whl (468 kB)
#    ---------------------------------------- 0.0/468.2 kB ? eta -:--:--
#    --- ----------------------------------- 41.0/468.2 kB 991.0 kB/s eta 0:00:01
#    ----- --------------------------------- 71.7/468.2 kB 787.7 kB/s eta 0:00:01
#    --------- ------------------------------ 112.6/468.2 kB 1.1 MB/s eta 0:00:01
#    ----------------- ---------------------- 204.8/468.2 kB 1.4 MB/s eta 0:00:01
#    -------------------------- ------------- 307.2/468.2 kB 1.6 MB/s eta 0:00:01
#    ------------------------------- -------- 368.6/468.2 kB 1.6 MB/s eta 0:00:01
#    ------------------------------------ --- 430.1/468.2 kB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 468.2/468.2 kB 1.7 MB/s eta 0:00:00
# Installing collected packages: pymongo
# Successfully installed pymongo-4.5.0
# WARNING: Ignoring invalid distribution ~ymongo (C:\ProgramData\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ymongo (C:\ProgramData\anaconda3\Lib\site-packages)
